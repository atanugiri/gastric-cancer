# %% [markdown]
# ## Read gene expression file

# %%
import pandas as pd
import os

# Change to project root only if currently inside the 'notebooks' folder
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

# Set path relative to notebook location
file_path = os.path.join("data", "expression profile(8863 genes).csv")

# Read the CSV and set first column as index
expression_df = pd.read_csv(file_path, index_col=0)

# Preview
print(f"expression_df shape = {expression_df.shape}\n")
# print(expression_df.head(2))
# Out:
# expression_df shape = (8863, 623)

# %% [markdown]
# ## Find overlapping genes among gastric cancer, hypercholesterolemia, and obesity datasets

# %% [markdown]
# ### hypercholesterolemia genes

# %%
# chol_file = ('/Users/atanugiri/Downloads/gastric cancer data analysis/'
# 'Hypercholesterolemia_gene_links_updated_final.xlsx')

# df_chol = pd.read_excel(chol_file, skiprows=2)

# # Extract genes from specified locations
# genes_part1 = df_chol.iloc[0:27, 1]
# genes_part2 = df_chol.iloc[28:82, 0]
# genes_part3 = df_chol.iloc[83:178, 0]

# # Concatenate all parts into a single list
# chol_genes = pd.concat([genes_part1, genes_part2, genes_part3]).dropna().tolist()

# chol_genes = [clean_gene_name(g) for g in chol_genes]
# print(chol_genes)

# %% [markdown]
# ### Obesity genes

# %%
# obesity_file = ('/Users/atanugiri/Downloads/gastric cancer data analysis/'
# 'obesity_gene_links_updated_final.xlsx')

# df_obesity = pd.read_excel(obesity_file)

# print(df_obesity.head(2))

# obesity_genes = df_obesity["Gene Name"].dropna().tolist()
# obesity_genes = [clean_gene_name(g) for g in obesity_genes]
# print(obesity_genes)

# %% [markdown]
# ### Common genes

# %%
# gc_genes = df_sorted.index
# gc_genes = [clean_gene_name(g) for g in gc_genes]

# common_genes_gc_chol = set(chol_genes) & set(gc_genes)
# print(f"{len(common_genes_gc_chol)} common GC and Chol genes found:\n{common_genes_gc_chol}")
# print("\n")

# common_genes_gc_ob = set(obesity_genes) & set(gc_genes)
# print(f"{len(common_genes_gc_ob)} common GC and Obesity genes found:\n{common_genes_gc_ob}")
# print("\n")

# common_genes_gc_chol_ob = set(gc_genes) & set(chol_genes) & set(obesity_genes)
# print(f"{len(common_genes_gc_chol_ob)} common GC and Chol and Obesity genes found:\n{common_genes_gc_chol_ob}")

# %% [markdown]
# ## Order genes by expression

# %%
gene_variance = expression_df.var(axis=1).sort_values(ascending=False)
top_genes = gene_variance.head(20).index
top_genes
# Out:
# Index(['PGA3', 'PGA4', 'PGA5', 'LIPF', 'ATP4A', 'GKN1', 'PGC', 'ATP4B', 'GIF',
#        'MUC17', 'GKN2', 'OLFM4', 'CST1', 'DMBT1', 'XIST', 'REG4', 'CEACAM5',
#        'DAZ1', 'CHIA', 'RPS4Y1'],
#       dtype='object')

# %%
# import matplotlib.pyplot as plt

# # Transpose to shape: (patients, genes)
# expression_df.loc[top_genes].T.plot(kind='box', figsize=(12, 6))

# plt.title("Top 20 Most Variable Genes Across Patients")
# plt.ylabel("Expression Level")
# plt.xticks(rotation=90)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### CD36 rank by expression

# %%
# Get variance ranking of CD36
cd36_variance = expression_df.var(axis=1).loc["CD36"]
rank = expression_df.var(axis=1).rank(ascending=False).loc["CD36"]
print(f"CD36 variance: {cd36_variance:.4f}, Rank: {int(rank)} out of {expression_df.shape[0]}")
# Out:
# CD36 variance: 2.3383, Rank: 5624 out of 8863

# %% [markdown]
# ## Prepare data for downstream analysis

# %% [markdown]
# ### Load clinical_df

# %%
import pandas as pd
import os

# Set path relative to notebook location
file_path = os.path.join("data", "tcga_gdc_clinical_data.tsv")

columns_to_use = ['Sample ID', 'Diagnosis Age', 'Biopsy Site', 'Disease Free (Months)', 
                 'Disease Free Status', 'Fraction Genome Altered', 'ICD-10 Classification',
                 'Mutation Count', 'Overall Survival (Months)', 'Overall Survival Status',
                 'AJCC Pathologic M-Stage', 'AJCC Pathologic N-Stage', 'AJCC Pathologic Stage',
                 'AJCC Pathologic T-Stage', 'Race Category', 'Sex']

# Read the file with tab separator and selected columns
clinical_df = pd.read_csv(file_path, sep='\t', usecols=columns_to_use)

# Convert status to numeric
status_map = {'0:LIVING': 0, '1:DECEASED': 1}
clinical_df["Overall Survival Status"] = clinical_df["Overall Survival Status"].map(status_map)

# print(f"clinical_df preview:\n{clinical_df.head(n=2)}\n")
print(f"clinical_df shape = {clinical_df.shape}")
# Out:
# clinical_df shape = (443, 16)

# %% [markdown]
# ### Merge expression_df and clinical_df

# %%
import os
import sys
import importlib

# Add 'python files' folder (relative to project root)
python_files_path = os.path.abspath(os.path.join("python files"))
if python_files_path not in sys.path:
    sys.path.append(python_files_path)

# Step 2: Import and reload
import merge_expression_and_clinical
importlib.reload(merge_expression_and_clinical)
from merge_expression_and_clinical import merge_expression_and_clinical

# Step 3: Run function
merged_df, aligned_expression_df = merge_expression_and_clinical(expression_df, clinical_df, "CD36")
assert list(aligned_expression_df.columns) == list(merged_df["Sample ID"])

print(f"merged_df shape: {merged_df.shape}\n")

# Save to results folder
output_path = os.path.join("results", "CD36_merged_data.xlsx")
merged_df.to_excel(output_path, index=False)
# Out:
# merged_df shape: (413, 17)

# %% [markdown]
# ## Survival status analysis

# %%
merged_df["Overall Survival Status"].value_counts(dropna=False)
# Out:
# Overall Survival Status
# 0.0    249
# 1.0    163
# NaN      1
# Name: count, dtype: int64

# %% [markdown]
# ### CD36 expression by survival status

# %%
import matplotlib.pyplot as plt
from plot_grouped_expression import plot_grouped_expression

fig, ax = plot_grouped_expression(
    df=merged_df,
    y_col="CD36 Expression",
    group_col="Overall Survival Status",
    palette={0.0: "blue", 1.0: "red"},
    order=[0.0, 1.0]
)

fig.tight_layout()
fig.savefig("results/CD36_Expression_by_Overall_Survival_Status_box.pdf", dpi=300)
plt.show()
# Out:
# t-test: t = 2.743, p = 6.441e-03

# %% [markdown]
# ## Survival months analysis

# %%
merged_df["Overall Survival (Months)"].describe()
# Out:
# count    408.000000
# mean      18.745169
# std       17.448266
# min        0.000000
# 25%        7.917214
# 50%       14.044021
# 75%       24.835742
# max      122.207622
# Name: Overall Survival (Months), dtype: float64

# %% [markdown]
# Split into High vs. Low Expression

# %%
# Step 1: Copy merged_df
df_expr_split = merged_df.copy()

# Step 2: Calculate median CD36 expression
threshold = df_expr_split["CD36 Expression"].median()

# Step 3: Add binary group label based on median
df_expr_split["CD36 Expression Level"] = [
    "High" if val >= threshold else "Low"
    for val in df_expr_split["CD36 Expression"]
]

# %% [markdown]
# Visualize Survival Months by CD36 expression level

# %%
from plot_grouped_expression import plot_grouped_expression

fig, ax = plot_grouped_expression(
    df=df_expr_split,
    y_col="Overall Survival (Months)",
    group_col="CD36 Expression Level",
    palette={"Low": "blue", "High": "red"},
    order=["Low", "High"]
)

fig.tight_layout()
fig.savefig("results/Overall_Survival_Months_by_CD36_Expression_Level_box.pdf", dpi=300)
plt.show()
# Out:
# t-test: t = -1.684, p = 9.289e-02

# %% [markdown]
# ### KM survival curve by CD36 expression

# %%
from plot_km_with_hr import plot_km_with_hr

fig, ax, cph_model = plot_km_with_hr(
    df_expr_split,
    time_col="Overall Survival (Months)",
    event_col="Overall Survival Status",
    group_col="CD36 Expression Level"
)

fig.savefig("results/CD36_KM.pdf", dpi=300)

# %% [markdown]
# ## Sex effect study

# %% [markdown]
# ### Compare CD36 Expression Between Male and Female

# %%
merged_df["Sex"].value_counts(dropna=False)
# Out:
# Sex
# Male      267
# Female    146
# Name: count, dtype: int64

# %%
from plot_grouped_expression import plot_grouped_expression

fig, ax = plot_grouped_expression(
    df=merged_df,
    y_col="CD36 Expression",
    group_col="Sex",
    palette={"Male": "blue", "Female": "red"},
    order=["Male", "Female"]
)

fig.tight_layout()
fig.savefig("results/CD36_Expression_by_Sex_box.pdf", dpi=300)
plt.show()
# Out:
# t-test: t = 0.035, p = 9.723e-01

# %% [markdown]
# ### Compare Survival Months by Sex

# %%
from plot_grouped_expression import plot_grouped_expression

fig, ax = plot_grouped_expression(
    df=merged_df,
    y_col="Overall Survival (Months)",
    group_col="Sex",
    palette={"Male": "blue", "Female": "red"},
    order=["Male", "Female"]
)

fig.tight_layout()
fig.savefig("results/Overall_Survival_Months_by_Sex_box.pdf", dpi=300)
plt.show()
# Out:
# t-test: t = 0.335, p = 7.379e-01

# %% [markdown]
# ### KM survival curve by Sex

# %%
import importlib
import plot_km_with_hr
importlib.reload(plot_km_with_hr)
from plot_km_with_hr import plot_km_with_hr

fig, ax, cph_sex = plot_km_with_hr(
    clinical_df=df_expr_split,
    time_col="Overall Survival (Months)",
    event_col="Overall Survival Status",
    group_col="Sex",
    group_high_label="Male",       # coded as 1
)

fig.savefig("results/Sex_KM.pdf", dpi=300)

# %% [markdown]
# ## Race effect study

# %% [markdown]
# ### Boxplot of CD36 Expression by Race

# %%
merged_df["Race Category"].value_counts(dropna=False)
# Out:
# Race Category
# WHITE                                        259
# ASIAN                                         86
# NaN                                           55
# BLACK OR AFRICAN AMERICAN                     12
# NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER      1
# Name: count, dtype: int64

# %%
# Step 1: Define races of interest
selected_races = ["WHITE", "ASIAN", "BLACK OR AFRICAN AMERICAN"]

# Step 2: Filter from merged_df (not just clinical_df)
filtered_race_df = merged_df[merged_df["Race Category"].isin(selected_races)].copy()

# %%
from plot_grouped_expression import plot_grouped_expression

fig, ax = plot_grouped_expression(
    df=filtered_race_df,
    y_col="CD36 Expression",
    group_col="Race Category",
    palette={
        "WHITE": "blue",
        "ASIAN": "green",
        "BLACK OR AFRICAN AMERICAN": "purple"
    },
    order=["WHITE", "ASIAN", "BLACK OR AFRICAN AMERICAN"],
    plot_type="box"
)

# Customize plot
ax.set_xticks(range(3))
ax.set_xticklabels(["White", "Asian", "Black or\nAfrican American"])
fig.tight_layout()
fig.savefig("results/CD36_Expression_by_Race_box.pdf", dpi=300)
plt.show()
# Out:
# ANOVA: F = 4.998, p = 7.234e-03

# %% [markdown]
# ## Analysis of cancer stage

# %%
# Step 1: Copy merged_df to preserve the original
df_stage = merged_df.copy()

# Step 2: Extract stage group (I, II, III, IV)
df_stage["Stage Group"] = (
    df_stage["AJCC Pathologic Stage"]
    .str.extract(r"(Stage\s+I{1,3}V?)")[0]
)

from plot_grouped_expression import plot_grouped_expression

fig, ax = plot_grouped_expression(
    df=df_stage,
    y_col="CD36 Expression",
    group_col="Stage Group",
    order=["Stage I", "Stage II", "Stage III", "Stage IV"],
)

fig.tight_layout()
fig.savefig("results/CD36_Expression_by_Cancer_stage_box.pdf", dpi=300)
plt.show()
# Out:
# ANOVA: F = 3.477, p = 1.613e-02

# %%
df_stage["Stage Group"].value_counts(dropna=False)
# Out:
# Stage Group
# Stage III    168
# Stage II     121
# Stage I       58
# Stage IV      41
# NaN           25
# Name: count, dtype: int64

# %% [markdown]
# ## Volcano Plot

# %% [markdown]
# ### Volcano plot with FDR

# %%
from plot_volcano_with_fdr import plot_volcano_with_fdr

# Alive vs Deceased, FDR correction
fig, ax, volcano_df = plot_volcano_with_fdr(
    aligned_expression_df,
    merged_df,
    label_col="Overall Survival Status",
    group1_label=0,
    group2_label=1,
    use_fdr=True,
)

fig.savefig("results/CD36_volcano_plot_with_fdr.pdf", dpi=300)

# %%
from scipy.stats import pearsonr, spearmanr

# Drop missing values
df_clean = merged_df[['Diagnosis Age', 'CD36 Expression']].dropna()

# Pearson
pearson_corr, p_pearson = pearsonr(df_clean['Diagnosis Age'], df_clean['CD36 Expression'])

# Spearman
spearman_corr, p_spearman = spearmanr(df_clean['Diagnosis Age'], df_clean['CD36 Expression'])

print(f"Pearson r = {pearson_corr:.3f}, p = {p_pearson:.3g}")
print(f"Spearman rho = {spearman_corr:.3f}, p = {p_spearman:.3g}")
# Out:
# Pearson r = -0.076, p = 0.125
# Spearman rho = -0.062, p = 0.214

# %% [markdown]
# ### Scatter Plot with Regression Line

# %%
import seaborn as sns
sns.set(style='whitegrid')

sns.lmplot(
    data=df_clean,
    x='Diagnosis Age',
    y='CD36 Expression',
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)
plt.title("CD36 Expression vs Diagnosis Age")
plt.show()

# %% [markdown]
# ## Biopsy site study

# %% [markdown]
# ### Summary of Biopsy Site

# %%
import importlib
import plot_grouped_expression
importlib.reload(plot_grouped_expression)
from plot_grouped_expression import plot_grouped_expression

# Count biopsy site levels
site_counts = merged_df['Biopsy Site'].value_counts()

# Keep only those with 2 or more samples
valid_sites = site_counts[site_counts >= 2].index

# Filter dataframe
filtered_df = merged_df[merged_df['Biopsy Site'].isin(valid_sites)]

# Plot
fig, ax = plot_grouped_expression(
    df=filtered_df,
    y_col="CD36 Expression",
    group_col="Biopsy Site",
    plot_type="bar"
)

plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
fig.tight_layout()
plt.show()
# Out:
# ANOVA: F = 2.192, p = 6.912e-02

# %% [markdown]
# ## Cancer subtype analysis

# %% [markdown]
# ### Combine expression_df and clinical_df containing subtype

# %%
import pandas as pd
import os

# Load clinical subtype data
file_path = os.path.join("data", "tcga_pan_can_atlas_2018_clinical_data.tsv")
# file_path = 'tcga_pan_can_atlas_2018_clinical_data.tsv'
columns_to_use = ['Sample ID', 'Subtype']

# Read the file with tab separator and selected columns
clinical_sub_df = pd.read_csv(file_path, sep='\t', usecols=columns_to_use)
print(f"clinical_sub_df shape: {clinical_sub_df.shape}\n")

merged_sub_df, aligned_expression_df = merge_expression_and_clinical(expression_df, clinical_sub_df, "CD36")
assert list(aligned_expression_df.columns) == list(merged_sub_df["Sample ID"])

print(f"merged_sub_df shape: {merged_sub_df.shape}\n")
# print(f"merged_df preview:\n{merged_df.head(2)}\n")

# Export to Excel
output_path = os.path.join("results", "CD36_cancer_type_data.xlsx")
merged_sub_df.to_excel(output_path, index=False)

# Filter out 'STAD_POLE' from Subtype column
# merged_sub_df = merged_sub_df[merged_sub_df["Subtype"] != "STAD_POLE"]
# Out:
# clinical_sub_df shape: (440, 2)
#
# merged_sub_df shape: (410, 3)

# %% [markdown]
# ### Boxplot

# %%
import importlib
import plot_grouped_expression
importlib.reload(plot_grouped_expression)
from plot_grouped_expression import plot_grouped_expression


fig, ax = plot_grouped_expression(
    df=merged_sub_df,
    y_col="CD36 Expression",
    group_col="Subtype",
    plot_type="box"
)

# Customize plot
ax.set_xticks(range(5))
ax.set_xticklabels(["CIN", "EBV", "GS", "MSI", "POLE"])
ax.set_title("CD36 Expression by Molecular Subtype", fontsize=14)
fig.tight_layout()
fig.savefig("results/CD36_Expression_by_Molecular_Subtype.pdf", dpi=300)
plt.show()
# Out:
# ANOVA: F = 8.975, p = 6.242e-07

# %%
merged_sub_df["Subtype"].value_counts(dropna=False)
# Out:
# Subtype
# STAD_CIN    220
# STAD_MSI     73
# STAD_GS      50
# STAD_EBV     30
# NaN          30
# Name: count, dtype: int64

# %% [markdown]
# ####
